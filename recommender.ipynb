# %%
# !pip install pandas numpy scikit-learn nltk
# Out:
# Requirement already satisfied: pandas in c:\users\hande\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\hande\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\hande\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: nltk in c:\users\hande\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hande\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hande\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hande\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\hande\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\hande\anaconda3\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\hande\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click in c:\users\hande\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hande\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\hande\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: six>=1.5 in c:\users\hande\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\hande\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import pandas as pd
import numpy as np
import pickle

# %%
df = pd.read_csv("tmdb_top_10k_movies_2026.csv.csv")

df = df[["title", "overview"]].dropna()
df.head()
# Out:
#                       title                                           overview
# 0  The Shawshank Redemption  Imprisoned in the 1940s for the double murder ...
# 1             The Godfather  Spanning the years 1945 to 1955, a chronicle o...
# 2     The Godfather Part II  In the continuing saga of the Corleone crime f...
# 3          Schindler's List  The true story of how businessman Oskar Schind...
# 4              12 Angry Men  The defense and the prosecution have rested an...

# %%
import re

def clean(text):
    text = text.lower()
    text = re.sub("[^a-zA-Z ]", "", text)
    return text

df["overview"] = df["overview"].apply(clean)

# %%
# convert text to vector
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words="english")

vectors = tfidf.fit_transform(df["overview"])

# %%
# similarity matrix
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vectors)

# %%
# save files
pickle.dump(df, open("movies.pkl", "wb"))
pickle.dump(similarity, open("similarity.pkl", "wb"))

print("✅ Model saved")
# Out:
# ✅ Model saved
